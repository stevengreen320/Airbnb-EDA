# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
# linear modelling
import statsmodels.api as sm
from scipy.stats import linregress
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
# metrics
from sklearn.metrics import mean_squared_error
import seaborn as sn
from census import Census

# Census API Key
from config import api_key
c = Census(api_key, year=2017)

# %%
df=pd.read_csv("Airbnb_Texas_Rentals.csv")
df
# Out:
#        Unnamed: 0 average_rate_per_night bedrooms_count         city  \
# 0               1                   $27               2       Humble
# 1               2                  $149               4  San Antonio
# 2               3                   $59               1      Houston
# 3               4                   $60               1        Bryan
# 4               5                   $75               2   Fort Worth
# ...           ...                    ...            ...          ...
# 18254       18255                   $60               1       Dallas
# 18255       18256                   $99               2  San Antonio
# 18256       18257                   $13               1       Dallas
# 18257       18258                   $65               2  San Antonio
# 18258       18259                   $75               1  San Antonio
#
#       date_of_listing                                        description  \
# 0              May-16  Welcome to stay in private room with queen bed...
# 1              Nov-10  Stylish, fully remodeled home in upscale NW – ...
# 2              Jan-17  'River house on island close to the city' \nA ...
# 3              Feb-16  Private bedroom in a cute little home situated...
# 4              Feb-17  Welcome to our original 1920's home. We recent...
# ...               ...                                                ...
# 18254          Mar-13  An entire 1 bedroom 700+sqft condo in the hear...
# 18255          Jun-15  An inviting 1920's cottage home in a popular u...
# 18256          Dec-16  Amazing 3BHK Apartment in a picturesque Commun...
# 18257          Oct-16  My quaint and cozy home is conveniently locate...
# 18258          Jul-15  Cute brand new, modern, guest house (we call i...
#
#         latitude  longitude  \
# 0      30.020138 -95.293996
# 1      29.503068 -98.447688
# 2      29.829352 -95.081549
# 3      30.637304 -96.337846
# 4      32.747097 -97.286434
# ...          ...        ...
# 18254  32.892303 -96.772049
# 18255  29.452893 -98.486756
# 18256  33.001955 -96.777615
# 18257  29.450142 -98.505333
# 18258  29.425508 -98.466833
#
#                                                    title  \
# 0        2 Private rooms/bathroom 10min from IAH airport
# 1      Unique Location! Alamo Heights - Designer Insp...
# 2                              River house near the city
# 3                           Private Room Close to Campus
# 4                                              The Porch
# ...                                                  ...
# 18254                     Quiet comfort living in Dallas
# 18255                     Midtown Cottage Near Riverwalk
# 18256                                    Room in Dallas!
# 18257                             Vibrant Spacious Loft!
# 18258    Brand New Modern Pod in Historic Dignowity Hill
#
#                                                      url
# 0      https://www.airbnb.com/rooms/18520444?location...
# 1      https://www.airbnb.com/rooms/17481455?location...
# 2      https://www.airbnb.com/rooms/16926307?location...
# 3      https://www.airbnb.com/rooms/11839729?location...
# 4      https://www.airbnb.com/rooms/17325114?location...
# ...                                                  ...
# 18254  https://www.airbnb.com/rooms/1011576?location=...
# 18255  https://www.airbnb.com/rooms/18766940?location...
# 18256  https://www.airbnb.com/rooms/18719059?location...
# 18257  https://www.airbnb.com/rooms/18179329?location...
# 18258  https://www.airbnb.com/rooms/16318144?location...
#
# [18259 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18259 entries, 0 to 18258
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              18259 non-null  int64
#  1   average_rate_per_night  18231 non-null  object
#  2   bedrooms_count          18256 non-null  object
#  3   city                    18259 non-null  object
#  4   date_of_listing         18259 non-null  object
#  5   description             18257 non-null  object
#  6   latitude                18225 non-null  float64
#  7   longitude               18225 non-null  float64
#  8   title                   18256 non-null  object
#  9   url                     18259 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 1.4+ MB

# %%
df.count()
# Out:
# Unnamed: 0                18259
# average_rate_per_night    18231
# bedrooms_count            18256
# city                      18259
# date_of_listing           18259
# description               18257
# latitude                  18225
# longitude                 18225
# title                     18256
# url                       18259
# dtype: int64

# %%
clean_df = df.dropna()
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18217 entries, 0 to 18258
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              18217 non-null  int64
#  1   average_rate_per_night  18217 non-null  object
#  2   bedrooms_count          18217 non-null  object
#  3   city                    18217 non-null  object
#  4   date_of_listing         18217 non-null  object
#  5   description             18217 non-null  object
#  6   latitude                18217 non-null  float64
#  7   longitude               18217 non-null  float64
#  8   title                   18217 non-null  object
#  9   url                     18217 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 1.5+ MB

# %%
# summary data frame
clean_df2 = clean_df.loc[:, ["city", "date_of_listing", "bedrooms_count", "average_rate_per_night", "latitude", "longitude"]]
clean_df2
# Out:
#               city date_of_listing bedrooms_count average_rate_per_night  \
# 0           Humble          May-16              2                   $27
# 1      San Antonio          Nov-10              4                  $149
# 2          Houston          Jan-17              1                   $59
# 3            Bryan          Feb-16              1                   $60
# 4       Fort Worth          Feb-17              2                   $75
# ...            ...             ...            ...                    ...
# 18254       Dallas          Mar-13              1                   $60
# 18255  San Antonio          Jun-15              2                   $99
# 18256       Dallas          Dec-16              1                   $13
# 18257  San Antonio          Oct-16              2                   $65
# 18258  San Antonio          Jul-15              1                   $75
#
#         latitude  longitude
# 0      30.020138 -95.293996
# 1      29.503068 -98.447688
# 2      29.829352 -95.081549
# 3      30.637304 -96.337846
# 4      32.747097 -97.286434
# ...          ...        ...
# 18254  32.892303 -96.772049
# 18255  29.452893 -98.486756
# 18256  33.001955 -96.777615
# 18257  29.450142 -98.505333
# 18258  29.425508 -98.466833
#
# [18217 rows x 6 columns]

# %%
clean_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18217 entries, 0 to 18258
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    18217 non-null  object
#  1   date_of_listing         18217 non-null  object
#  2   bedrooms_count          18217 non-null  object
#  3   average_rate_per_night  18217 non-null  object
#  4   latitude                18217 non-null  float64
#  5   longitude               18217 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 996.2+ KB

# %%
clean_df2["clean_dates"]=[x+"-2017" for x in clean_df2.date_of_listing]
clean_df2["clean_dates"]=pd.to_datetime(clean_df2["clean_dates"])

clean_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18217 entries, 0 to 18258
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    18217 non-null  object
#  1   date_of_listing         18217 non-null  object
#  2   bedrooms_count          18217 non-null  object
#  3   average_rate_per_night  18217 non-null  object
#  4   latitude                18217 non-null  float64
#  5   longitude               18217 non-null  float64
#  6   clean_dates             18217 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 1.1+ MB

# %%
clean_df2.head()
# Out:
#           city date_of_listing bedrooms_count average_rate_per_night  \
# 0       Humble          May-16              2                   $27
# 1  San Antonio          Nov-10              4                  $149
# 2      Houston          Jan-17              1                   $59
# 3        Bryan          Feb-16              1                   $60
# 4   Fort Worth          Feb-17              2                   $75
#
#     latitude  longitude clean_dates
# 0  30.020138 -95.293996  2017-05-16
# 1  29.503068 -98.447688  2017-11-10
# 2  29.829352 -95.081549  2017-01-17
# 3  30.637304 -96.337846  2017-02-16
# 4  32.747097 -97.286434  2017-02-17

# %%
clean_df2["months"]=[x.month for x in clean_df2.clean_dates]
clean_df2.head()
# Out:
#           city date_of_listing bedrooms_count average_rate_per_night  \
# 0       Humble          May-16              2                   $27
# 1  San Antonio          Nov-10              4                  $149
# 2      Houston          Jan-17              1                   $59
# 3        Bryan          Feb-16              1                   $60
# 4   Fort Worth          Feb-17              2                   $75
#
#     latitude  longitude clean_dates  months
# 0  30.020138 -95.293996  2017-05-16       5
# 1  29.503068 -98.447688  2017-11-10      11
# 2  29.829352 -95.081549  2017-01-17       1
# 3  30.637304 -96.337846  2017-02-16       2
# 4  32.747097 -97.286434  2017-02-17       2

# %%
# Create the bins in which Data will be held
# Bins are  12-1-2016, 7-1-2016, 1-1-2018
bins = [0, 3, 6, 9, 12]

# Create the names for the five bins
group_names = ["First", "Second", "Third", "Fourth"]

# %%
clean_df2["Date_Quarter"] = pd.cut(clean_df2["months"], bins, labels=group_names, include_lowest=True)
clean_df2
# Out:
#               city date_of_listing bedrooms_count average_rate_per_night  \
# 0           Humble          May-16              2                   $27
# 1      San Antonio          Nov-10              4                  $149
# 2          Houston          Jan-17              1                   $59
# 3            Bryan          Feb-16              1                   $60
# 4       Fort Worth          Feb-17              2                   $75
# ...            ...             ...            ...                    ...
# 18254       Dallas          Mar-13              1                   $60
# 18255  San Antonio          Jun-15              2                   $99
# 18256       Dallas          Dec-16              1                   $13
# 18257  San Antonio          Oct-16              2                   $65
# 18258  San Antonio          Jul-15              1                   $75
#
#         latitude  longitude clean_dates  months Date Bin    Date  \
# 0      30.020138 -95.293996  2017-05-16       5   Second  Second
# 1      29.503068 -98.447688  2017-11-10      11   Fourth  Fourth
# 2      29.829352 -95.081549  2017-01-17       1    First   First
# 3      30.637304 -96.337846  2017-02-16       2    First   First
# 4      32.747097 -97.286434  2017-02-17       2    First   First
# ...          ...        ...         ...     ...      ...     ...
# 18254  32.892303 -96.772049  2017-03-13       3    First   First
# 18255  29.452893 -98.486756  2017-06-15       6   Second  Second
# 18256  33.001955 -96.777615  2017-12-16      12   Fourth  Fourth
# 18257  29.450142 -98.505333  2017-10-16      10   Fourth  Fourth
# 18258  29.425508 -98.466833  2017-07-15       7    Third   Third
#
#       Date(Quarter) Date_Quarter
# 0            Second       Second
# 1            Fourth       Fourth
# 2             First        First
# 3             First        First
# 4             First        First
# ...             ...          ...
# 18254         First        First
# 18255        Second       Second
# 18256        Fourth       Fourth
# 18257        Fourth       Fourth
# 18258         Third        Third
#
# [18217 rows x 12 columns]

# %%
# summary data frame
clean_df3 = clean_df2.loc[:, ["city", "Date_Quarter", "bedrooms_count", "average_rate_per_night", "latitude", "longitude"]]
clean_df3
# Out:
#               city Date_Quarter bedrooms_count average_rate_per_night  \
# 0           Humble       Second              2                   $27
# 1      San Antonio       Fourth              4                  $149
# 2          Houston        First              1                   $59
# 3            Bryan        First              1                   $60
# 4       Fort Worth        First              2                   $75
# ...            ...          ...            ...                    ...
# 18254       Dallas        First              1                   $60
# 18255  San Antonio       Second              2                   $99
# 18256       Dallas       Fourth              1                   $13
# 18257  San Antonio       Fourth              2                   $65
# 18258  San Antonio        Third              1                   $75
#
#         latitude  longitude
# 0      30.020138 -95.293996
# 1      29.503068 -98.447688
# 2      29.829352 -95.081549
# 3      30.637304 -96.337846
# 4      32.747097 -97.286434
# ...          ...        ...
# 18254  32.892303 -96.772049
# 18255  29.452893 -98.486756
# 18256  33.001955 -96.777615
# 18257  29.450142 -98.505333
# 18258  29.425508 -98.466833
#
# [18217 rows x 6 columns]
